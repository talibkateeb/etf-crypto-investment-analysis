# %%
# Import required libraries and dependencies
import json
import requests
import os
import pandas as pd
import numpy as np
import plotly.express as px
import hvplot.pandas
from pathlib import Path
from dotenv import load_dotenv
from MCForecastTools import MCSimulation

# %%
# Load the environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
# Read from csv to df for ETFs Historical data (OHLC)
fan_df = pd.read_csv(Path('data/etf_historical_data/FAN_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

ftxl_df = pd.read_csv(Path('data/etf_historical_data/FTXL_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

icln_df = pd.read_csv(Path('data/etf_historical_data/ICLN_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

itb_df = pd.read_csv(Path('data/etf_historical_data/ITB_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

mj_df = pd.read_csv(Path('data/etf_historical_data/MJ_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

nlr_df = pd.read_csv(Path('data/etf_historical_data/NLR_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

potx_df = pd.read_csv(Path('data/etf_historical_data/POTX_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

smh_df = pd.read_csv(Path('data/etf_historical_data/SMH_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

soxl_df = pd.read_csv(Path('data/etf_historical_data/SOXL_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

tan_df = pd.read_csv(Path('data/etf_historical_data/TAN_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

urnm_df = pd.read_csv(Path('data/etf_historical_data/URNM_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

xhb_df = pd.read_csv(Path('data/etf_historical_data/XHB_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)

yolo_df = pd.read_csv(Path('data/etf_historical_data/YOLO_historical.csv'), index_col= 'Date', parse_dates=True, infer_datetime_format=True)


# Read from csv to df for Crypto Historical data (OHLC)

binance_coin_df = pd.read_csv(Path('data/crypto_historical/Binance_Coin_Historical.csv'), index_col='Date', infer_datetime_format=True, parse_dates=True)

bitcoin_cash_df = pd.read_csv(Path('data/crypto_historical/Bitcoin_Cash_Historical.csv'), index_col='Date', infer_datetime_format=True, parse_dates=True)

bitcoin_df = pd.read_csv(Path('data/crypto_historical/Bitcoin_Historical.csv'), index_col='Date', infer_datetime_format=True, parse_dates=True)

cardano_df = pd.read_csv(Path('data/crypto_historical/Cardano_Historical.csv'), index_col='Date', infer_datetime_format=True, parse_dates=True)

ethereum_df = pd.read_csv(Path('data/crypto_historical/Ethereum_Historical.csv'), index_col='Date', infer_datetime_format=True, parse_dates=True)

tether_df = pd.read_csv(Path('data/crypto_historical/Binance_Coin_Historical.csv'), index_col='Date', infer_datetime_format=True, parse_dates=True)

# %%
# Drop all columns except close/last from ETFs dataframes

fan_df = fan_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

ftxl_df = ftxl_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

icln_df = icln_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

itb_df = itb_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

mj_df = mj_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

nlr_df = nlr_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

potx_df = potx_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

smh_df = smh_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

soxl_df = soxl_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

tan_df = tan_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

urnm_df = urnm_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

xhb_df = xhb_df.drop(columns=['Volume', 'Open', 'High', 'Low'])

yolo_df = yolo_df.drop(columns=['Volume', 'Open', 'High', 'Low'])


# Drop all columns except close from crypto dataframes

binance_coin_df = binance_coin_df.drop(columns=['Change %', 'High', 'Low', 'Open', 'Vol.'])
binance_coin_df = binance_coin_df.rename(columns={'Price': 'Close'})

bitcoin_cash_df = bitcoin_cash_df.drop(columns=['Change %', 'High', 'Low', 'Open', 'Vol.'])
bitcoin_cash_df = bitcoin_cash_df.rename(columns={'Price': 'Close'})

bitcoin_df = bitcoin_df.drop(columns=['Change %', 'High', 'Low', 'Open', 'Vol.'])
bitcoin_df = bitcoin_df.rename(columns={'Price': 'Close'})

cardano_df = cardano_df.drop(columns=['Change %', 'High', 'Low', 'Open', 'Vol.'])
cardano_df = cardano_df.rename(columns={'Price': 'Close'})

ethereum_df = ethereum_df.drop(columns=['Change %', 'High', 'Low', 'Open', 'Vol.'])
ethereum_df = ethereum_df.rename(columns={'Price': 'Close'})

tether_df = tether_df.drop(columns=['Change %', 'High', 'Low', 'Open', 'Vol.'])
tether_df = tether_df.rename(columns={'Price': 'Close'})

# %%
# Calculate daily returns for all assets ETFs and Crypto, and add a column showcasing Daily Returns

# ETF dataframes
fan_df['Daily Returns'] = fan_df.pct_change().dropna()

ftxl_df['Daily Returns'] = ftxl_df.pct_change().dropna()

icln_df['Daily Returns'] = icln_df.pct_change().dropna()

itb_df['Daily Returns'] = itb_df.pct_change().dropna()

mj_df['Daily Returns'] = mj_df.pct_change().dropna()

nlr_df['Daily Returns'] = nlr_df.pct_change().dropna()

potx_df['Daily Returns'] = potx_df.pct_change().dropna()

smh_df['Daily Returns'] = smh_df.pct_change().dropna()

soxl_df['Daily Returns'] = soxl_df.pct_change().dropna()

tan_df['Daily Returns'] = tan_df.pct_change().dropna()

urnm_df['Daily Returns'] = urnm_df.pct_change().dropna()

xhb_df['Daily Returns'] = xhb_df.pct_change().dropna()

yolo_df['Daily Returns'] = yolo_df.pct_change().dropna()

# Crypto Dataframes
binance_coin_df['Daily Returns'] = binance_coin_df.pct_change().dropna()


bitcoin_cash_df['Close'] = bitcoin_cash_df['Close'].iloc[:].str.replace(',', '').astype(float)

bitcoin_cash_df['Daily Returns'] = bitcoin_cash_df.pct_change().dropna()


bitcoin_df['Close'] = bitcoin_df['Close'].iloc[:].str.replace(',', '').astype(float)

bitcoin_df['Daily Returns'] = bitcoin_df.pct_change().dropna()


cardano_df['Daily Returns'] = cardano_df.pct_change().dropna()


ethereum_df['Close'] = ethereum_df['Close'].iloc[:].str.replace(',', '').astype(float)

ethereum_df['Daily Returns'] = ethereum_df.pct_change().dropna()


tether_df['Daily Returns'] = tether_df.pct_change().dropna()

# %%
# Interactive line plot for ETFs Daily Returns

(fan_df['Daily Returns'].hvplot.line(title='ETFs Daily Returns', label='FAN') 
 * ftxl_df['Daily Returns'].hvplot.line(label='FXTL')
 * icln_df['Daily Returns'].hvplot.line(label='ICLN')
 * itb_df['Daily Returns'].hvplot.line(label='ITB')
 * mj_df['Daily Returns'].hvplot.line(label='MJ')
 * nlr_df['Daily Returns'].hvplot.line(label='NLR')
 * potx_df['Daily Returns'].hvplot.line(label='POTX')
 * smh_df['Daily Returns'].hvplot.line(label='SMH')
 * soxl_df['Daily Returns'].hvplot.line(label='SOXL')
 * tan_df['Daily Returns'].hvplot.line(label='TAN')
 * urnm_df['Daily Returns'].hvplot.line(label='URNM')
 * xhb_df['Daily Returns'].hvplot.line(label='XHB')
 * yolo_df['Daily Returns'].hvplot.line(label='YOLO')
)
# Out:
# :Overlay
#    .Curve.FAN  :Curve   [Date]   (Daily Returns)
#    .Curve.FXTL :Curve   [Date]   (Daily Returns)
#    .Curve.ICLN :Curve   [Date]   (Daily Returns)
#    .Curve.ITB  :Curve   [Date]   (Daily Returns)
#    .Curve.MJ   :Curve   [Date]   (Daily Returns)
#    .Curve.NLR  :Curve   [Date]   (Daily Returns)
#    .Curve.POTX :Curve   [Date]   (Daily Returns)
#    .Curve.SMH  :Curve   [Date]   (Daily Returns)
#    .Curve.SOXL :Curve   [Date]   (Daily Returns)
#    .Curve.TAN  :Curve   [Date]   (Daily Returns)
#    .Curve.URNM :Curve   [Date]   (Daily Returns)
#    .Curve.XHB  :Curve   [Date]   (Daily Returns)
#    .Curve.YOLO :Curve   [Date]   (Daily Returns)

# %%
# Interactive line plot for Crypto's Daily Returns

(binance_coin_df['Daily Returns'].hvplot.line(title='Cryptocurrency Daily Returns', label='Binance Coin')
 * bitcoin_cash_df['Daily Returns'].hvplot.line(label='Bitcoin Cash')
 * bitcoin_df['Daily Returns'].hvplot.line(label='Bitcoin')
 * cardano_df['Daily Returns'].hvplot.line(label='Cardano')
 * ethereum_df['Daily Returns'].hvplot.line(label='Ethereum')
 * tether_df['Daily Returns'].hvplot.line(label='Tether')
)
# Out:
# :Overlay
#    .Curve.Binance_Coin :Curve   [Date]   (Daily Returns)
#    .Curve.Bitcoin_Cash :Curve   [Date]   (Daily Returns)
#    .Curve.Bitcoin      :Curve   [Date]   (Daily Returns)
#    .Curve.Cardano      :Curve   [Date]   (Daily Returns)
#    .Curve.Ethereum     :Curve   [Date]   (Daily Returns)
#    .Curve.Tether       :Curve   [Date]   (Daily Returns)

# %%
# Interactive line plot for Daily Returns for both ETF and Crypto

(fan_df['Daily Returns'].hvplot.line(title='Daily Returns for both ETFs and Crypto', label='FAN') 
 * ftxl_df['Daily Returns'].hvplot.line(label='FXTL')
 * icln_df['Daily Returns'].hvplot.line(label='ICLN')
 * itb_df['Daily Returns'].hvplot.line(label='ITB')
 * mj_df['Daily Returns'].hvplot.line(label='MJ')
 * nlr_df['Daily Returns'].hvplot.line(label='NLR')
 * potx_df['Daily Returns'].hvplot.line(label='POTX')
 * smh_df['Daily Returns'].hvplot.line(label='SMH')
 * soxl_df['Daily Returns'].hvplot.line(label='SOXL')
 * tan_df['Daily Returns'].hvplot.line(label='TAN')
 * urnm_df['Daily Returns'].hvplot.line(label='URNM')
 * xhb_df['Daily Returns'].hvplot.line(label='XHB')
 * yolo_df['Daily Returns'].hvplot.line(label='YOLO')
 * binance_coin_df['Daily Returns'].hvplot.line(label='Binance Coin')
 * bitcoin_cash_df['Daily Returns'].hvplot.line(label='Bitcoin Cash')
 * bitcoin_df['Daily Returns'].hvplot.line(label='Bitcoin')
 * cardano_df['Daily Returns'].hvplot.line(label='Cardano')
 * ethereum_df['Daily Returns'].hvplot.line(label='Ethereum')
 * tether_df['Daily Returns'].hvplot.line(label='Tether')
)
# Out:
# :Overlay
#    .Curve.FAN          :Curve   [Date]   (Daily Returns)
#    .Curve.FXTL         :Curve   [Date]   (Daily Returns)
#    .Curve.ICLN         :Curve   [Date]   (Daily Returns)
#    .Curve.ITB          :Curve   [Date]   (Daily Returns)
#    .Curve.MJ           :Curve   [Date]   (Daily Returns)
#    .Curve.NLR          :Curve   [Date]   (Daily Returns)
#    .Curve.POTX         :Curve   [Date]   (Daily Returns)
#    .Curve.SMH          :Curve   [Date]   (Daily Returns)
#    .Curve.SOXL         :Curve   [Date]   (Daily Returns)
#    .Curve.TAN          :Curve   [Date]   (Daily Returns)
#    .Curve.URNM         :Curve   [Date]   (Daily Returns)
#    .Curve.XHB          :Curve   [Date]   (Daily Returns)
#    .Curve.YOLO         :Curve   [Date]   (Daily Returns)
#    .Curve.Binance_Coin :Curve   [Date]   (Daily Returns)
#    .Curve.Bitcoin_Cash :Curve   [Date]   (Daily Returns)
#    .Curve.Bitcoin      :Curve   [Date]   (Daily Returns)
# ...

# %%
# Interactive box plot for ETFs Daily Returns

(fan_df['Daily Returns'].hvplot.box(title='ETFs Daily Returns', label='FAN') 
 * ftxl_df['Daily Returns'].hvplot.box(label='FXTL')
 * icln_df['Daily Returns'].hvplot.box(label='ICLN')
 * itb_df['Daily Returns'].hvplot.box(label='ITB')
 * mj_df['Daily Returns'].hvplot.box(label='MJ')
 * nlr_df['Daily Returns'].hvplot.box(label='NLR')
 * potx_df['Daily Returns'].hvplot.box(label='POTX')
 * smh_df['Daily Returns'].hvplot.box(label='SMH')
 * soxl_df['Daily Returns'].hvplot.box(label='SOXL')
 * tan_df['Daily Returns'].hvplot.box(label='TAN')
 * urnm_df['Daily Returns'].hvplot.box(label='URNM')
 * xhb_df['Daily Returns'].hvplot.box(label='XHB')
 * yolo_df['Daily Returns'].hvplot.box(label='YOLO')
)
# Out:
# ...
# :Overlay
#    .BoxWhisker.FAN  :BoxWhisker   (Daily Returns)
#    .BoxWhisker.FXTL :BoxWhisker   (Daily Returns)
#    .BoxWhisker.ICLN :BoxWhisker   (Daily Returns)
#    .BoxWhisker.ITB  :BoxWhisker   (Daily Returns)
#    .BoxWhisker.MJ   :BoxWhisker   (Daily Returns)
#    .BoxWhisker.NLR  :BoxWhisker   (Daily Returns)
#    .BoxWhisker.POTX :BoxWhisker   (Daily Returns)
#    .BoxWhisker.SMH  :BoxWhisker   (Daily Returns)
#    .BoxWhisker.SOXL :BoxWhisker   (Daily Returns)
#    .BoxWhisker.TAN  :BoxWhisker   (Daily Returns)
#    .BoxWhisker.URNM :BoxWhisker   (Daily Returns)
#    .BoxWhisker.XHB  :BoxWhisker   (Daily Returns)
#    .BoxWhisker.YOLO :BoxWhisker   (Daily Returns)

# %%
# Interactive box plot for Crypto's Daily Returns

(binance_coin_df['Daily Returns'].hvplot.box(title='Cryptocurrency Daily Returns', label='Binance Coin')
 * bitcoin_cash_df['Daily Returns'].hvplot.box(label='Bitcoin Cash')
 * bitcoin_df['Daily Returns'].hvplot.box(label='Bitcoin')
 * cardano_df['Daily Returns'].hvplot.box(label='Cardano')
 * ethereum_df['Daily Returns'].hvplot.box(label='Ethereum')
 * tether_df['Daily Returns'].hvplot.box(label='Tether')
)
# Out:
# ...
# :Overlay
#    .BoxWhisker.Binance_Coin :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Bitcoin_Cash :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Bitcoin      :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Cardano      :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Ethereum     :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Tether       :BoxWhisker   (Daily Returns)

# %%
# Interactive box plot for Daily Returns for both ETF and Crypto

(fan_df['Daily Returns'].hvplot.box(title='Daily Returns for both ETFs and Crypto', label='FAN') 
 * ftxl_df['Daily Returns'].hvplot.box(label='FXTL')
 * icln_df['Daily Returns'].hvplot.box(label='ICLN')
 * itb_df['Daily Returns'].hvplot.box(label='ITB')
 * mj_df['Daily Returns'].hvplot.box(label='MJ')
 * nlr_df['Daily Returns'].hvplot.box(label='NLR')
 * potx_df['Daily Returns'].hvplot.box(label='POTX')
 * smh_df['Daily Returns'].hvplot.box(label='SMH')
 * soxl_df['Daily Returns'].hvplot.box(label='SOXL')
 * tan_df['Daily Returns'].hvplot.box(label='TAN')
 * urnm_df['Daily Returns'].hvplot.box(label='URNM')
 * xhb_df['Daily Returns'].hvplot.box(label='XHB')
 * yolo_df['Daily Returns'].hvplot.box(label='YOLO')
 * binance_coin_df['Daily Returns'].hvplot.box(label='Binance Coin')
 * bitcoin_cash_df['Daily Returns'].hvplot.box(label='Bitcoin Cash')
 * bitcoin_df['Daily Returns'].hvplot.box(label='Bitcoin')
 * cardano_df['Daily Returns'].hvplot.box(label='Cardano')
 * ethereum_df['Daily Returns'].hvplot.box(label='Ethereum')
 * tether_df['Daily Returns'].hvplot.box(label='Tether')
)
# Out:
# ...
# :Overlay
#    .BoxWhisker.FAN          :BoxWhisker   (Daily Returns)
#    .BoxWhisker.FXTL         :BoxWhisker   (Daily Returns)
#    .BoxWhisker.ICLN         :BoxWhisker   (Daily Returns)
#    .BoxWhisker.ITB          :BoxWhisker   (Daily Returns)
#    .BoxWhisker.MJ           :BoxWhisker   (Daily Returns)
#    .BoxWhisker.NLR          :BoxWhisker   (Daily Returns)
#    .BoxWhisker.POTX         :BoxWhisker   (Daily Returns)
#    .BoxWhisker.SMH          :BoxWhisker   (Daily Returns)
#    .BoxWhisker.SOXL         :BoxWhisker   (Daily Returns)
#    .BoxWhisker.TAN          :BoxWhisker   (Daily Returns)
#    .BoxWhisker.URNM         :BoxWhisker   (Daily Returns)
#    .BoxWhisker.XHB          :BoxWhisker   (Daily Returns)
#    .BoxWhisker.YOLO         :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Binance_Coin :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Bitcoin_Cash :BoxWhisker   (Daily Returns)
#    .BoxWhisker.Bitcoin      :BoxWhisker   (Daily Returns)
# ...

# %%
# Add Cumulative Returns Column to ETF dataframes
fan_df['Cumulative Returns'] = (1 + fan_df['Daily Returns']).cumprod()

ftxl_df['Cumulative Returns'] = (1 + ftxl_df['Daily Returns']).cumprod()

icln_df['Cumulative Returns'] = (1 + icln_df['Daily Returns']).cumprod()

itb_df['Cumulative Returns'] = (1 + itb_df['Daily Returns']).cumprod()

mj_df['Cumulative Returns'] = (1 + mj_df['Daily Returns']).cumprod()

nlr_df['Cumulative Returns'] = (1 + nlr_df['Daily Returns']).cumprod()

potx_df['Cumulative Returns'] = (1 + potx_df['Daily Returns']).cumprod()

smh_df['Cumulative Returns'] = (1 + smh_df['Daily Returns']).cumprod()

soxl_df['Cumulative Returns'] = (1 + soxl_df['Daily Returns']).cumprod()

tan_df['Cumulative Returns'] = (1 + tan_df['Daily Returns']).cumprod()

urnm_df['Cumulative Returns'] = (1 + urnm_df['Daily Returns']).cumprod()

xhb_df['Cumulative Returns'] = (1 + xhb_df['Daily Returns']).cumprod()

yolo_df['Cumulative Returns'] = (1 + yolo_df['Daily Returns']).cumprod()

# %%
# Add Cumulative Returns Column to Crypto dataframes

binance_coin_df['Cumulative Returns'] = (1 + binance_coin_df['Daily Returns']).cumprod()

bitcoin_cash_df['Cumulative Returns'] = (1 + bitcoin_cash_df['Daily Returns']).cumprod()

bitcoin_df['Cumulative Returns'] = (1 + bitcoin_df['Daily Returns']).cumprod()

cardano_df['Cumulative Returns'] = (1 + cardano_df['Daily Returns']).cumprod()

ethereum_df['Cumulative Returns'] = (1 + ethereum_df['Daily Returns']).cumprod()

tether_df['Cumulative Returns'] = (1 + tether_df['Daily Returns']).cumprod()

# %%
# Interactive line plot for ETFs Cumulative Returns

(fan_df['Cumulative Returns'].hvplot.line(title='ETFs Cumulative Returns', label='FAN') 
 * ftxl_df['Cumulative Returns'].hvplot.line(label='FXTL')
 * icln_df['Cumulative Returns'].hvplot.line(label='ICLN')
 * itb_df['Cumulative Returns'].hvplot.line(label='ITB')
 * mj_df['Cumulative Returns'].hvplot.line(label='MJ')
 * nlr_df['Cumulative Returns'].hvplot.line(label='NLR')
 * potx_df['Cumulative Returns'].hvplot.line(label='POTX')
 * smh_df['Cumulative Returns'].hvplot.line(label='SMH')
 * soxl_df['Cumulative Returns'].hvplot.line(label='SOXL')
 * tan_df['Cumulative Returns'].hvplot.line(label='TAN')
 * urnm_df['Cumulative Returns'].hvplot.line(label='URNM')
 * xhb_df['Cumulative Returns'].hvplot.line(label='XHB')
 * yolo_df['Cumulative Returns'].hvplot.line(label='YOLO')
)
# Out:
# :Overlay
#    .Curve.FAN  :Curve   [Date]   (Cumulative Returns)
#    .Curve.FXTL :Curve   [Date]   (Cumulative Returns)
#    .Curve.ICLN :Curve   [Date]   (Cumulative Returns)
#    .Curve.ITB  :Curve   [Date]   (Cumulative Returns)
#    .Curve.MJ   :Curve   [Date]   (Cumulative Returns)
#    .Curve.NLR  :Curve   [Date]   (Cumulative Returns)
#    .Curve.POTX :Curve   [Date]   (Cumulative Returns)
#    .Curve.SMH  :Curve   [Date]   (Cumulative Returns)
#    .Curve.SOXL :Curve   [Date]   (Cumulative Returns)
#    .Curve.TAN  :Curve   [Date]   (Cumulative Returns)
#    .Curve.URNM :Curve   [Date]   (Cumulative Returns)
#    .Curve.XHB  :Curve   [Date]   (Cumulative Returns)
#    .Curve.YOLO :Curve   [Date]   (Cumulative Returns)

# %%
# Interactive line plot for Crypto's Cumulative Returns

(binance_coin_df['Cumulative Returns'].hvplot.line(title='Cryptocurrency Cumulative Returns', label='Binance Coin')
 * bitcoin_cash_df['Cumulative Returns'].hvplot.line(label='Bitcoin Cash')
 * bitcoin_df['Cumulative Returns'].hvplot.line(label='Bitcoin')
 * cardano_df['Cumulative Returns'].hvplot.line(label='Cardano')
 * ethereum_df['Cumulative Returns'].hvplot.line(label='Ethereum')
 * tether_df['Cumulative Returns'].hvplot.line(label='Tether')
)
# Out:
# :Overlay
#    .Curve.Binance_Coin :Curve   [Date]   (Cumulative Returns)
#    .Curve.Bitcoin_Cash :Curve   [Date]   (Cumulative Returns)
#    .Curve.Bitcoin      :Curve   [Date]   (Cumulative Returns)
#    .Curve.Cardano      :Curve   [Date]   (Cumulative Returns)
#    .Curve.Ethereum     :Curve   [Date]   (Cumulative Returns)
#    .Curve.Tether       :Curve   [Date]   (Cumulative Returns)

# %%
# Interactive line plot for Cumulative Returns for both ETF and Crypto

(fan_df['Cumulative Returns'].hvplot.line(title='Cumulative Returns for both ETFs and Crypto', label='FAN') 
 * ftxl_df['Cumulative Returns'].hvplot.line(label='FXTL')
 * icln_df['Cumulative Returns'].hvplot.line(label='ICLN')
 * itb_df['Cumulative Returns'].hvplot.line(label='ITB')
 * mj_df['Cumulative Returns'].hvplot.line(label='MJ')
 * nlr_df['Cumulative Returns'].hvplot.line(label='NLR')
 * potx_df['Cumulative Returns'].hvplot.line(label='POTX')
 * smh_df['Cumulative Returns'].hvplot.line(label='SMH')
 * soxl_df['Cumulative Returns'].hvplot.line(label='SOXL')
 * tan_df['Cumulative Returns'].hvplot.line(label='TAN')
 * urnm_df['Cumulative Returns'].hvplot.line(label='URNM')
 * xhb_df['Cumulative Returns'].hvplot.line(label='XHB')
 * yolo_df['Cumulative Returns'].hvplot.line(label='YOLO')
 * binance_coin_df['Cumulative Returns'].hvplot.line(label='Binance Coin')
 * bitcoin_cash_df['Cumulative Returns'].hvplot.line(label='Bitcoin Cash')
 * bitcoin_df['Cumulative Returns'].hvplot.line(label='Bitcoin')
 * cardano_df['Cumulative Returns'].hvplot.line(label='Cardano')
 * ethereum_df['Cumulative Returns'].hvplot.line(label='Ethereum')
 * tether_df['Cumulative Returns'].hvplot.line(label='Tether')
)
# Out:
# :Overlay
#    .Curve.FAN          :Curve   [Date]   (Cumulative Returns)
#    .Curve.FXTL         :Curve   [Date]   (Cumulative Returns)
#    .Curve.ICLN         :Curve   [Date]   (Cumulative Returns)
#    .Curve.ITB          :Curve   [Date]   (Cumulative Returns)
#    .Curve.MJ           :Curve   [Date]   (Cumulative Returns)
#    .Curve.NLR          :Curve   [Date]   (Cumulative Returns)
#    .Curve.POTX         :Curve   [Date]   (Cumulative Returns)
#    .Curve.SMH          :Curve   [Date]   (Cumulative Returns)
#    .Curve.SOXL         :Curve   [Date]   (Cumulative Returns)
#    .Curve.TAN          :Curve   [Date]   (Cumulative Returns)
#    .Curve.URNM         :Curve   [Date]   (Cumulative Returns)
#    .Curve.XHB          :Curve   [Date]   (Cumulative Returns)
#    .Curve.YOLO         :Curve   [Date]   (Cumulative Returns)
#    .Curve.Binance_Coin :Curve   [Date]   (Cumulative Returns)
#    .Curve.Bitcoin_Cash :Curve   [Date]   (Cumulative Returns)
# ...

# %%
# Create Dataframe with all standard deviations of daily returns of all assets

standard_dev_data = [['Fan', fan_df['Daily Returns'].std()], 
                     ['FTXL', ftxl_df['Daily Returns'].std()],
                     ['ICLN', icln_df['Daily Returns'].std()],
                     ['ITB', itb_df['Daily Returns'].std()],
                     ['MJ', mj_df['Daily Returns'].std()],
                     ['NLR', nlr_df['Daily Returns'].std()],
                     ['POTX', potx_df['Daily Returns'].std()],
                     ['SMH', smh_df['Daily Returns'].std()],
                     ['SOXL', soxl_df['Daily Returns'].std()],
                     ['TAN', tan_df['Daily Returns'].std()],
                     ['URNM', urnm_df['Daily Returns'].std()],
                     ['XHB', xhb_df['Daily Returns'].std()],
                     ['YOLO', yolo_df['Daily Returns'].std()],
                     ['BNB', binance_coin_df['Daily Returns'].std()],
                     ['BCH', bitcoin_cash_df['Daily Returns'].std()],
                     ['BTC', bitcoin_df['Daily Returns'].std()],
                     ['ADA', cardano_df['Daily Returns'].std()],
                     ['ETH', ethereum_df['Daily Returns'].std()],
                     ['USDT', tether_df['Daily Returns'].std()]
                    ]

assets_std_df = pd.DataFrame(standard_dev_data, columns=['Ticker', 'Standard Deviation'])
assets_std_df = assets_std_df.set_index('Ticker')

# %%
# Interactive bar plot showing standard deviation of daily returns of all assets

assets_std_df.hvplot.bar(title='Standard Deviation of Daily Returns for ETFs and Crypto', x='Ticker')
# Out:
# :Bars   [Ticker]   (Standard Deviation)

# %%
# Create a new dataframe with Annualized Standard Deviation of daily returns of all assets

assets_annualized_std_df = assets_std_df
assets_annualized_std_df['Standard Deviation'] = assets_annualized_std_df['Standard Deviation'] * np.sqrt(252)
assets_annualized_std_df = assets_annualized_std_df.rename(columns={'Standard Deviation':'Annualized Standard Deviation'})

# %%
# Interactive bar plot showing annualized standard deviation of daily returns of all assets

assets_annualized_std_df.hvplot.bar(title='Annualized Standard Deviation of Daily Returns for ETFs and Crypto', x='Ticker')
# Out:
# :Bars   [Ticker]   (Annualized Standard Deviation)

# %%
# Read dataframes from csv files for the market caps of the etfs and the cryptocurrencies

crypto_market_cap_df = pd.read_csv('data/market_cap/crypto_market_cap.csv')

etf_market_cap_df = pd.read_csv('data/market_cap/etf_market_cap.csv')

# Change string to float for values
etf_market_cap_df['Market Capitalizaton'] = etf_market_cap_df['Market Capitalizaton'].iloc[:].str.replace(',', '').astype(float)

crypto_market_cap_df['Market Capitalizaton'] = crypto_market_cap_df['Market Capitalizaton'].iloc[:].str.replace(',', '').astype(float)

# rename columns so pandas can concatentate the dataferames nicely
etf_market_cap_df = etf_market_cap_df.rename(columns={'ETF':'Ticker'})

crypto_market_cap_df = crypto_market_cap_df.rename(columns={'Coin':'Ticker'})

# concatenate the dataframes for a new dataframe with all market capitalizations
market_cap_df = pd.concat([etf_market_cap_df, crypto_market_cap_df])

# %%
market_cap_df.hvplot.bar(title= 'Market Capitalization of all ETFs and Cryptocurrencies', x='Ticker', width=1000, rot=90)
# Out:
# :Bars   [Ticker]   (Market Capitalizaton)
